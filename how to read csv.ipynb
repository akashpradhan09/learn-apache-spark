# %%
spark

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Basics').getOrCreate()

# %%
from pyspark.sql.types import StructField,StringType,IntegerType,StructType
schema = StructType([
      StructField("DEST_COUNTRY_NAME",StringType(),True),
      StructField("ORIGIN_COUNTRY_NAME",StringType(),True),
      StructField("count",IntegerType(),True),

    ])

# %%
ddl_schema = "DEST_COUNTRY_NAME String, ORIGIN_COUNTRY_NAME String, count Int"

# %%
flight_df = spark.read.format("csv")\
.option("header","false")\
.option("skipRows",1)\
.schema(schema)\
.option("mode","PERMISSIVE")\
.load("/Volumes/spark_data/dev/spark_data_volume/flight-data/csv/2010-summary.csv")
flight_df.show()

# %%
emp_df = spark.read.format("csv")\
    .option("header","true")\
    .option("inferSchema","true")\
    .option("mode","PERMISSIVE")\
    .load("/Volumes/spark_data/dev/spark_data_volume/emp_data.csv")
emp_df.show()

# %% [markdown]
# how to print bad record

# %%
from pyspark.sql.types import StringType,StructField,StringType,IntegerType
emp_bad_schema = StructType([
    StructField("id",IntegerType(),True),
    StructField("name",StringType(),True),
    StructField("age",IntegerType(),True),
    StructField("salary",IntegerType(),True),
    StructField("address",StringType(),True),
    StructField("nominee",StringType(),True),
    StructField("_corrupt_record",StringType(),True)

])

# %%
emp_bad_df = spark.read.format("csv")\
    .option("header",True)\
    .schema(emp_bad_schema)\
    .option("mode","Permissive")\
    .load("/Volumes/spark_data/dev/spark_data_volume/emp_data.csv")

emp_bad_df.show(truncate=False)

# %% [markdown]
# where to store bad records

# %%
emp_bad1_df = spark.read.format("csv")\
.option("header",True)\
.schema(emp_bad_schema)\
.option("badRecordsPath","/Volumes/spark_data/dev/spark_data_volume/bad_records/")\
.load("/Volumes/spark_data/dev/spark_data_volume/emp_data.csv") 

emp_bad1_df.show(truncate=False)

# %%
emp_corrup_df = spark.read.json("/Volumes/spark_data/dev/spark_data_volume/bad_records/20260324T042202/bad_records/part-00000-51920a14-10a2-4342-9e6a-d062e0082a86")

display(emp_corrup_df)

# %%
spark
