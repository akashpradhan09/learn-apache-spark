# %%
pip install parquet-tools

# %%
import pyarrow as pa
import pyarrow.parquet as pq

parquet_file = pq.ParquetFile(r"/Volumes/spark_data/dev/spark_data_volume/flight-data/parquet/2010-summary.parquet/part-r-00000-1a9822ba-b8fb-4d8e-844a-ea30d0801b9e.gz.parquet")

parquet_file.metadata

# %%
parquet_file.metadata.row_group(0)

# %%
parquet_file.metadata.row_group(0).column(0)

# %%
parquet_file.metadata.row_group(0).column(0).statistics

# %%
df = spark.read.parquet("/Volumes/spark_data/dev/spark_data_volume/flight-data/parquet/2010-summary.parquet/")

df.show()

# %%
df.inspect()
