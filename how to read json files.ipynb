# %%
spark.read.format("json")\
.option("mode","Permissive")\
.option("inferSchema","true")\
.load("/Volumes/spark_data/dev/spark_data_volume/line_delimited_json.jsonl").show()

# %%
spark.read.format("json")\
.option("mode","PERMISSIVE")\
.option("multiline","true")\
.option("inferSchema","true")\
.load("/Volumes/spark_data/dev/spark_data_volume/multi-line_incorrect.json").show()

# %%
spark.read.format("json")\
.option("mode","PERMISSIVE")\
.option("inferSchema","true")\
.load("/Volumes/spark_data/dev/spark_data_volume/corrupted_json.json").show()
